# %%
#Aim: Write a program to implement a simple form of a recurrent neural network e.g., (4-to-1 RNN) to
#      show that the quantity of rain on a certain day also depends on the values of the previous day.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define sequence of 50 days of rain data
rain_data = np.array([2.3, 1.5, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0,
                      2.5, 2.2, 2.4, 3.0, 2.1, 2.5, 3.2, 3.1, 1.9, 2.7,
                      2.2, 2.8, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0])

# Create input and output sequences for training
def create_sequences(values, time_steps):
    x = []
    y = []
    for i in range(len(values)-time_steps):
        x.append(values[i:i+time_steps])
        y.append(values[i+time_steps])
    return np.array(x), np.array(y)

time_steps = 4
x_train, y_train = create_sequences(rain_data, time_steps)

# Define RNN model
model = tf.keras.models.Sequential([
    tf.keras.layers.SimpleRNN(8, input_shape=(time_steps, 1)),
    tf.keras.layers.Dense(1)
])

# Compile model
model.compile(optimizer="adam", loss="mse")

# Train model
history = model.fit(x_train.reshape(-1, time_steps, 1), y_train, epochs=100)

# Plot loss over time
loss = history.history["loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.title("Training loss")
plt.legend()
plt.show()

# Test model on new sequence
test_sequence = np.array([2.5, 2.2, 2.8, 3.2])
x_test = np.array([test_sequence])
y_test = model.predict(x_test.reshape(-1, time_steps, 1))

# Print input, output, and prediction
print("Previous days' rain data:", test_sequence)
print("Expected rain amount for next day:", y_test[0][0])
prediction = model.predict(np.array([test_sequence]).reshape(1, time_steps, 1))
print("Prediction:", prediction[0][0])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 10s 6ms/step - loss: 12.0788
# Epoch 2/100
# 2/2 [==============================] - 0s 7ms/step - loss: 11.7935
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 11.5065
# Epoch 4/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.2193
# Epoch 5/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.9351
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.6526
# Epoch 7/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.3687
# Epoch 8/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.0853
# Epoch 9/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.8048
# Epoch 10/100
# 2/2 [==============================] - 0s 9ms/step - loss: 9.5254
# Epoch 11/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.2445
# Epoch 12/100
# 2/2 [==============================] - 0s 6ms/step - loss: 8.9705
# Epoch 13/100
# 2/2 [==============================] - 0s 7ms/step - loss: 8.6953
# Epoch 14/100
# 2/2 [==============================] - 0s 7ms/step - loss: 8.4195
# Epoch 15/100
# 2/2 [==============================] - 0s 4ms/step - loss: 8.1491
# Epoch 16/100
# 2/2 [==============================] - 0s 7ms/step - loss: 7.8798
# Epoch 17/100
# 2/2 [==============================] - 0s 6ms/step - loss: 7.6095
# Epoch 18/100
# 2/2 [==============================] - 0s 5ms/step - loss: 7.3420
# Epoch 19/100
# 2/2 [==============================] - 0s 5ms/step - loss: 7.0793
# Epoch 20/100
# 2/2 [==============================] - 0s 7ms/step - loss: 6.8143
# Epoch 21/100
# 2/2 [==============================] - 0s 14ms/step - loss: 6.5519
# Epoch 22/100
# 2/2 [==============================] - 0s 7ms/step - loss: 6.2912
# Epoch 23/100
# 2/2 [==============================] - 0s 6ms/step - loss: 6.0361
# Epoch 24/100
# 2/2 [==============================] - 0s 6ms/step - loss: 5.7782
# Epoch 25/100
# 2/2 [==============================] - 0s 110ms/step - loss: 5.5271
# Epoch 26/100
# 2/2 [==============================] - 0s 6ms/step - loss: 5.2754
# Epoch 27/100
# 2/2 [==============================] - 0s 6ms/step - loss: 5.0296
# Epoch 28/100
# 2/2 [==============================] - 0s 5ms/step - loss: 4.7900
# Epoch 29/100
# 2/2 [==============================] - 0s 7ms/step - loss: 4.5526
# Epoch 30/100
# 2/2 [==============================] - 0s 88ms/step - loss: 4.3246
# Epoch 31/100
# 2/2 [==============================] - 0s 7ms/step - loss: 4.0953
# Epoch 32/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.8873
# Epoch 33/100
# 2/2 [==============================] - 0s 8ms/step - loss: 3.6767
# Epoch 34/100
# 2/2 [==============================] - 0s 8ms/step - loss: 3.4736
# Epoch 35/100
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2861
# Epoch 36/100
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1090
# Epoch 37/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9336
# Epoch 38/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7690
# Epoch 39/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.6170
# Epoch 40/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2.4760
# Epoch 41/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3372
# Epoch 42/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2082
# Epoch 43/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0911
# Epoch 44/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9779
# Epoch 45/100
# 2/2 [==============================] - 0s 12ms/step - loss: 1.8734
# Epoch 46/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7750
# Epoch 47/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6820
# Epoch 48/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5995
# Epoch 49/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5170
# Epoch 50/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4445
# Epoch 51/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.3713
# Epoch 52/100
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3089
# Epoch 53/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2465
# Epoch 54/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1898
# Epoch 55/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1347
# Epoch 56/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0866
# Epoch 57/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0362
# Epoch 58/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9934
# Epoch 59/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9503
# Epoch 60/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9118
# Epoch 61/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8715
# Epoch 62/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8376
# Epoch 63/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8052
# Epoch 64/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7738
# Epoch 65/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.7456
# Epoch 66/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7187
# Epoch 67/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6923
# Epoch 68/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6684
# Epoch 69/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6463
# Epoch 70/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.6275
# Epoch 71/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6075
# Epoch 72/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5904
# Epoch 73/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5714
# Epoch 74/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5561
# Epoch 75/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5425
# Epoch 76/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5283
# Epoch 77/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5148
# Epoch 78/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5027
# Epoch 79/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4914
# Epoch 80/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.4814
# Epoch 81/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4709
# Epoch 82/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.4608
# Epoch 83/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4525
# Epoch 84/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4453
# Epoch 85/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.4367
# Epoch 86/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4294
# Epoch 87/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4230
# Epoch 88/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4163
# Epoch 89/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4106
# Epoch 90/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4053
# Epoch 91/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3995
# Epoch 92/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3948
# Epoch 93/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3904
# Epoch 94/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3866
# Epoch 95/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3820
# Epoch 96/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3783
# Epoch 97/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3754
# Epoch 98/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3726
# Epoch 99/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.3689
# Epoch 100/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3659
# Previous days' rain data: [2.5 2.2 2.8 3.2]
# Expected rain amount for next day: 1.9943197
# Prediction: 1.9943197
